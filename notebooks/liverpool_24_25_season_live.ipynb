# %%
import pandas as pd

# %%
# scraping fbref for latest Liverpool stats from 24/25 season
liverpool_df = pd.read_html('https://fbref.com/en/squads/822bd0ba/Liverpool-Stats',
                            attrs={"id":"stats_standard_9"})[0]

# %%
# print first 5 rows in dataset
liverpool_df.head(5)
# Out:
#     Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                 Player             Nation                Pos
# 0      Virgil van Dijk             nl NED                 DF
# 1     Ryan Gravenberch             nl NED                 MF
# 2        Mohamed Salah             eg EGY                 FW
# 3   Dominik Szoboszlai             hu HUN                 MF
# 4  Alexis Mac Allister             ar ARG                 MF
#
#   Unnamed: 3_level_0 Unnamed: 4_level_0 Playing Time             Performance  \
#                  Age                 MP       Starts    Min  90s         Gls
# 0             33-078                  5            5  450.0  5.0         0.0
# 1             22-131                  5            5  449.0  5.0         0.0
# 2             32-101                  5            5  442.0  4.9         3.0
# 3             23-335                  5            5  420.0  4.7         0.0
# ...

# %%
# printing last 5 rows in dataset
liverpool_df.tail(5)
# Out:
#    Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                Player             Nation                Pos
# 20        Wataru Endo             jp JPN                 MF
# 21          Joe Gomez            eng ENG                 DF
# 22    Vitezslav Jaros             cz CZE                 GK
# 23        Squad Total                NaN                NaN
# 24     Opponent Total                NaN                NaN
#
#    Unnamed: 3_level_0 Unnamed: 4_level_0 Playing Time             Performance  \
#                   Age                 MP       Starts    Min  90s         Gls
# 20             31-228                  1            0    1.0  0.0         0.0
# 21             27-124                  0            0    NaN  NaN         NaN
# 22             23-063                  0            0    NaN  NaN         NaN
# 23               27.5                  5           55  450.0  5.0        10.0
# ...

# %%
liverpool_df.col
# Out:
# MultiIndex([( 'Unnamed: 0_level_0',   'Player'),
#             ( 'Unnamed: 1_level_0',   'Nation'),
#             ( 'Unnamed: 2_level_0',      'Pos'),
#             ( 'Unnamed: 3_level_0',      'Age'),
#             ( 'Unnamed: 4_level_0',       'MP'),
#             (       'Playing Time',   'Starts'),
#             (       'Playing Time',      'Min'),
#             (       'Playing Time',      '90s'),
#             (        'Performance',      'Gls'),
#             (        'Performance',      'Ast'),
#             (        'Performance',      'G+A'),
#             (        'Performance',     'G-PK'),
#             (        'Performance',       'PK'),
#             (        'Performance',    'PKatt'),
#             (        'Performance',     'CrdY'),
#             (        'Performance',     'CrdR'),
#             (           'Expected',       'xG'),
#             (           'Expected',     'npxG'),
#             (           'Expected',      'xAG'),
# ...
